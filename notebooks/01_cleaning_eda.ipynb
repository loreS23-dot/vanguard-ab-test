# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.io import load_raw
from src.cleaning import clean_web, merge_all
import pandas as pd

demo, exp, w1, w2 = load_raw("../data")
web = pd.concat([w1, w2], ignore_index=True)
web = clean_web(web)
df = merge_all(demo, exp, web)

df.shape, df["process_step"].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 4
#       1 import sys, os
#       2 sys.path.append(os.path.abspath(".."))
# ----> 4 from src.io import load_raw
#       5 from src.cleaning import clean_web, merge_all
#       6 import pandas as pd
#
# ImportError: cannot import name 'load_raw' from 'src.io' (c:\Users\marcl\ironhack\PROYECTO TOP\vanguard-ab-test\src\io.py)
